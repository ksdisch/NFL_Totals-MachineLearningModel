# %% [markdown]
# # NFL Over Under Machine Learning

# %% [markdown]
# ## Pre Processing

# %%
# Import dependencies
from pathlib import Path
import pandas as pd
from matplotlib import pyplot as plt
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Import data
data = Path('nfl_data.csv')
df = pd.read_csv(data)
df.head()
# Out:
#    index        date  year  week        team_home_full team_home_abrv  \
# 0    353   12/2/2018  2018    13  Jacksonville Jaguars            JAX
# 1   4900   12/3/2000  2000    14     Carolina Panthers            CAR
# 2     61  12/19/2021  2021    15  Tampa Bay Buccaneers             TB
# 3   2364  12/12/2010  2010    14         Detroit Lions            DET
# 4   3150  11/26/2007  2007    12   Pittsburgh Steelers            PIT
#
#   team_home_combined      team_away_full team_away_abrv team_away_combined  \
# 0            JAX2018  Indianapolis Colts            IND            IND2018
# 1            CAR2000      St. Louis Rams            LAR            LAR2000
# 2             TB2021  New Orleans Saints             NO             NO2021
# 3            DET2010   Green Bay Packers             GB             GB2010
# 4            PIT2007      Miami Dolphins            MIA            MIA2007
#
#    ...  dvoa_overall_cumulative  dvoa_weighted_diff  dvoa_weighted_cumulative  \
# 0  ...                    0.039              -0.365                     0.081
# 1  ...                   -0.030              -0.362                    -0.052
# 2  ...                    0.323               0.261                     0.257
# 3  ...                    0.256              -0.174                     0.306
# 4  ...                   -0.040               0.361                    -0.193
#
#    dvoa_dave_diff  dvoa_dave_cumulative  team_home_dvoa_off_diff  \
# 0          -0.296                -0.138                   -0.097
# 1          -0.449                 0.091                    0.044
# 2           0.373                 0.161                   -0.036
# 3          -0.125                 0.113                    0.022
# 4           0.148                 0.014                   -0.100
#
#   dvoa_off_cumulative  team_away_dvoa_off_diff  dvoa_def_cumulative  \
# 0              -0.123                    0.079                0.053
# 1               0.148                   -0.076                0.028
# 2              -0.183                    0.126               -0.021
# 3              -0.142                    0.166                0.002
# 4               0.011                   -0.154               -0.043
#
#    comp_pace_avg
# 0       29.55125
# 1       29.46875
# 2       28.77750
# 3       29.62250
# 4       30.38250
#
# [5 rows x 56 columns]

# %%
# Define target variable
y = df['over_binary']

# Dropping columns that, after testing, were either irrelevant for the model or made no difference on the accuracy.
X = df.drop(columns=['index','over_binary', 'over_under_diff', 'score_total', 'date', 'team_home_full', 'team_home_abrv', 'team_home_combined',
                      'team_away_full', 'team_away_abrv', 'team_away_combined',
                      'team_favorite_abrv', 'weather_detail', 'score_home', 'score_away', 'dome_binary',
                      'humidity', 'year','favorite_spread','temperature','comp_pace_avg','team_home_dvoa_overall','team_away_dvoa_overall',
                   'team_home_def_pace_total','team_home_dvoa_dave','team_away_dvoa_dave',
                   'team_away_def_pace_total'])

X.head()
# Out:
#    week  over_under  wind_mph  team_home_off_pace_neutral  \
# 0    13        45.5        13                       32.27
# 1    14        58.0        13                       30.56
# 2    15        45.5         0                       28.66
# 3    14        46.0         0                       29.57
# 4    12        38.5         7                       33.94
#
#    team_home_def_pace_neutral  team_home_off_pace_total  team_home_comp_pace  \
# 0                       31.60                     28.18              30.1625
# 1                       30.57                     27.81              29.2250
# 2                       30.42                     26.58              28.1750
# 3                       32.07                     26.15              29.1250
# 4                       30.31                     31.31              30.6450
#
#    team_away_off_pace_neutral  team_away_def_pace_neutral  \
# 0                       28.53                       32.42
# 1                       30.65                       31.85
# 2                       31.03                       30.10
# 3                       31.53                       31.36
# 4                       31.61                       31.34
#
#    team_away_off_pace_total  ...  dvoa_overall_diff  dvoa_overall_cumulative  \
# 0                     26.30  ...             -0.209                    0.039
# 1                     28.43  ...             -0.336                   -0.030
# 2                     28.94  ...              0.229                    0.323
# 3                     29.92  ...             -0.214                    0.256
# 4                     27.99  ...              0.424                   -0.040
#
#    dvoa_weighted_diff  dvoa_weighted_cumulative  dvoa_dave_diff  \
# 0              -0.365                     0.081          -0.296
# 1              -0.362                    -0.052          -0.449
# 2               0.261                     0.257           0.373
# 3              -0.174                     0.306          -0.125
# 4               0.361                    -0.193           0.148
#
#    dvoa_dave_cumulative  team_home_dvoa_off_diff  dvoa_off_cumulative  \
# 0                -0.138                   -0.097               -0.123
# 1                 0.091                    0.044                0.148
# 2                 0.161                   -0.036               -0.183
# 3                 0.113                    0.022               -0.142
# 4                 0.014                   -0.100                0.011
#
#    team_away_dvoa_off_diff  dvoa_def_cumulative
# 0                    0.079                0.053
# 1                   -0.076                0.028
# 2                    0.126               -0.021
# 3                    0.166                0.002
# 4                   -0.154               -0.043
#
# [5 rows x 29 columns]

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
print(X_train.shape)
print(X_test.shape)
# Out:
# (3754, 29)
# (1252, 29)

# %%
# Creating and fitting a Standard Scaler with the training data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

# Scaling the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Linear Discriminant Analysis Classifier

# %%
classifier = LinearDiscriminantAnalysis(solver='svd') # No random_state parameter
classifier.fit(X_train_scaled, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
predictions = classifier.predict(X_test_scaled)
results = pd.DataFrame({'Prediction':predictions, 'Actual':y_test}).reset_index(drop=True)

# Calculating the confusion matrix.
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual Under", "Actual Over"], columns=["Predicted Under", "Predicted Over"])
lda_acc_score = accuracy_score(y_test, predictions)

# Print Accuracy Score and classification report
display(cm_df)
print(f"Accuracy Score : {lda_acc_score}")
print(classification_report(y_test, predictions))
# Out:
#               Predicted Under  Predicted Over
# Actual Under              367             265
# Actual Over               261             359
# Accuracy Score : 0.5798722044728435
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58       632
#            1       0.58      0.58      0.58       620
#
#     accuracy                           0.58      1252
#    macro avg       0.58      0.58      0.58      1252
# weighted avg       0.58      0.58      0.58      1252
