# %% [markdown]
# # NFL Over/Under Machine Learning

# %%
# Import Dependencies
from pathlib import Path
import pandas as pd
import os

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# ## Connecting to Database

# %%
# Create engine
engine = create_engine("postgresql://postgres:password@127.0.0.1:5432/NFL_Data")

# %%
# Reflect an existing database into a new model
Base = automap_base()

# %%
# Reflect the tables
Base.prepare(engine, reflect=True)

# %%
# Create session
session = Session(engine)

# %%
# Get data with query
query = session.execute('select * from nfl_ml_dataset')
dat = query.fetchall()

# %%
# Get column names in list
column_names = list(query.keys())

# %%
# Create pandas dataframe
df = pd.DataFrame(dat, columns=column_names)
df.head()
# Out:
#    index schedule_date  schedule_season  schedule_week team_home  \
# 0      1    1993-09-05             1993              1       BUF
# 1      2    1993-09-05             1993              1       CHI
# 2      3    1993-09-05             1993              1       CLE
# 3      4    1993-09-05             1993              1       DET
# 4      5    1993-09-05             1993              1        GB
#
#   team_home_full team_away team_away_full  score_home  score_away  ...  \
# 0        BUF1993        NE         NE1993          38          14  ...
# 1        CHI1993       NYG        NYG1993          20          26  ...
# 2        CLE1993       CIN        CIN1993          27          14  ...
# 3        DET1993       ATL        ATL1993          30          13  ...
# 4         GB1993       LAR        LAR1993          36           6  ...
#
#    dvoa_special_cumulative dvoa_special_difference dvoa_home_offense_matchup  \
# 0                     -5.6                     6.4                       9.6
# 1                      3.6                     1.8                     -15.2
# 2                      4.7                     5.7                       9.4
# 3                     11.9                     1.3                      -4.3
# 4                     -0.7                    11.1                      16.3
#
#   dvoa_away_offense_matchup composite_pace_average composite_pace_difference  \
# 0                     -17.7    26.2650000000000000                     3.600
# 1                       6.5    30.6750000000000000                     0.560
# 2                     -16.3    29.9425000000000000                     2.565
# 3                     -11.6    31.4300000000000000                      1.56
# 4                      -6.5    29.4900000000000000                     0.190
#
#   dvoa_offdefdiff_cumulative dvoa_offdefdiff_difference  \
# 0                      -23.3                       16.3
# 1                       -8.7                       29.9
# 2                      -40.5                       21.3
# 3                      -30.7                        0.9
# 4                      -29.6                        4.6
#
#   offense_matchup_cumulative offense_matchup_difference
# 0                       -8.1                       27.3
# 1                       -8.7                       21.7
# 2                       -6.9                       25.7
# 3                      -15.9                        7.3
# 4                        9.8                       22.8
#
# [5 rows x 51 columns]

# %%
# View columns, types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index                       7109 non-null   int64
#  1   schedule_date               7109 non-null   object
#  2   schedule_season             7109 non-null   int64
#  3   schedule_week               7109 non-null   int64
#  4   team_home                   7109 non-null   object
#  5   team_home_full              7109 non-null   object
#  6   team_away                   7109 non-null   object
#  7   team_away_full              7109 non-null   object
#  8   score_home                  7109 non-null   int64
#  9   score_away                  7109 non-null   int64
#  10  score_total                 7109 non-null   int64
#  11  over_under_line             7109 non-null   object
#  12  over_under_diff             7109 non-null   object
#  13  over_binary                 7109 non-null   object
#  14  spread_favorite             7109 non-null   object
#  15  home_total_dvoa             7109 non-null   object
#  16  home_weighted_dvoa          7109 non-null   object
#  17  home_offense_dvoa           7109 non-null   object
#  18  home_defense_dvoa           7109 non-null   object
#  19  home_special_dvoa           7109 non-null   object
#  20  home_off_def_difference     7109 non-null   object
#  21  home_sec_play_total         7109 non-null   object
#  22  home_sec_play_neutral       7109 non-null   object
#  23  home_sec_play_composite     7109 non-null   object
#  24  away_total_dvoa             7109 non-null   object
#  25  away_weighted_dvoa          7109 non-null   object
#  26  away_offense_dvoa           7109 non-null   object
#  27  away_defense_dvoa           7109 non-null   object
#  28  away_special_dvoa           7109 non-null   object
#  29  away_off_def_difference     7109 non-null   object
#  30  away_sec_play_total         7109 non-null   object
#  31  away_sec_play_neutral       7109 non-null   object
#  32  away_sec_play_composite     7109 non-null   object
#  33  dvoa_total_cumulative       7109 non-null   object
#  34  dvoa_total_difference       7109 non-null   object
#  35  dvoa_weighted_cumulative    7109 non-null   object
#  36  dvoa_weighted_difference    7109 non-null   object
#  37  dvoa_offense_cumulative     7109 non-null   object
#  38  dvoa_offense_difference     7109 non-null   object
#  39  dvoa_defense_cumulative     7109 non-null   object
#  40  dvoa_defense_difference     7109 non-null   object
#  41  dvoa_special_cumulative     7109 non-null   object
#  42  dvoa_special_difference     7109 non-null   object
#  43  dvoa_home_offense_matchup   7109 non-null   object
#  44  dvoa_away_offense_matchup   7109 non-null   object
#  45  composite_pace_average      7109 non-null   object
#  46  composite_pace_difference   7109 non-null   object
#  47  dvoa_offdefdiff_cumulative  7109 non-null   object
#  48  dvoa_offdefdiff_difference  7109 non-null   object
#  49  offense_matchup_cumulative  7109 non-null   object
#  50  offense_matchup_difference  7109 non-null   object
# dtypes: int64(6), object(45)
# memory usage: 2.8+ MB

# %%
# Change column data types
df[['over_under_line','over_under_diff', 'over_binary', 'spread_favorite', 'home_total_dvoa',
    'home_weighted_dvoa', 'home_offense_dvoa', 'home_defense_dvoa', 'home_special_dvoa', 
    'home_off_def_difference', 'home_sec_play_total', 'home_sec_play_neutral', 
    'home_sec_play_composite', 'away_total_dvoa', 'away_weighted_dvoa', 'away_offense_dvoa',
    'away_defense_dvoa', 'away_special_dvoa', 'away_off_def_difference', 
    'away_sec_play_total', 'away_sec_play_neutral', 'away_sec_play_composite', 
    'dvoa_total_cumulative', 'dvoa_total_difference', 'dvoa_weighted_cumulative', 
    'dvoa_weighted_difference', 'dvoa_offense_cumulative', 'dvoa_offense_difference',
    'dvoa_defense_cumulative', 'dvoa_defense_difference', 'dvoa_special_cumulative', 
    'dvoa_special_difference', 'dvoa_home_offense_matchup', 'dvoa_away_offense_matchup', 
    'composite_pace_average', 'composite_pace_difference', 'dvoa_offdefdiff_cumulative', 
    'dvoa_offdefdiff_difference', 'offense_matchup_cumulative', 'offense_matchup_difference']] = df[['over_under_line','over_under_diff', 'over_binary', 'spread_favorite', 'home_total_dvoa',
    'home_weighted_dvoa', 'home_offense_dvoa', 'home_defense_dvoa', 'home_special_dvoa', 
    'home_off_def_difference', 'home_sec_play_total', 'home_sec_play_neutral', 
    'home_sec_play_composite', 'away_total_dvoa', 'away_weighted_dvoa', 'away_offense_dvoa',
    'away_defense_dvoa', 'away_special_dvoa', 'away_off_def_difference', 
    'away_sec_play_total', 'away_sec_play_neutral', 'away_sec_play_composite', 
    'dvoa_total_cumulative', 'dvoa_total_difference', 'dvoa_weighted_cumulative', 
    'dvoa_weighted_difference', 'dvoa_offense_cumulative', 'dvoa_offense_difference',
    'dvoa_defense_cumulative', 'dvoa_defense_difference', 'dvoa_special_cumulative', 
    'dvoa_special_difference', 'dvoa_home_offense_matchup', 'dvoa_away_offense_matchup', 
    'composite_pace_average', 'composite_pace_difference', 'dvoa_offdefdiff_cumulative', 
    'dvoa_offdefdiff_difference', 'offense_matchup_cumulative', 'offense_matchup_difference']].apply(pd.to_numeric)

# %%
# View columns, types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   index                       7109 non-null   int64
#  1   schedule_date               7109 non-null   object
#  2   schedule_season             7109 non-null   int64
#  3   schedule_week               7109 non-null   int64
#  4   team_home                   7109 non-null   object
#  5   team_home_full              7109 non-null   object
#  6   team_away                   7109 non-null   object
#  7   team_away_full              7109 non-null   object
#  8   score_home                  7109 non-null   int64
#  9   score_away                  7109 non-null   int64
#  10  score_total                 7109 non-null   int64
#  11  over_under_line             7109 non-null   float64
#  12  over_under_diff             7109 non-null   float64
#  13  over_binary                 7109 non-null   float64
#  14  spread_favorite             7109 non-null   float64
#  15  home_total_dvoa             7109 non-null   float64
#  16  home_weighted_dvoa          7109 non-null   float64
#  17  home_offense_dvoa           7109 non-null   float64
#  18  home_defense_dvoa           7109 non-null   float64
#  19  home_special_dvoa           7109 non-null   float64
#  20  home_off_def_difference     7109 non-null   float64
#  21  home_sec_play_total         7109 non-null   float64
#  22  home_sec_play_neutral       7109 non-null   float64
#  23  home_sec_play_composite     7109 non-null   float64
#  24  away_total_dvoa             7109 non-null   float64
#  25  away_weighted_dvoa          7109 non-null   float64
#  26  away_offense_dvoa           7109 non-null   float64
#  27  away_defense_dvoa           7109 non-null   float64
#  28  away_special_dvoa           7109 non-null   float64
#  29  away_off_def_difference     7109 non-null   float64
#  30  away_sec_play_total         7109 non-null   float64
#  31  away_sec_play_neutral       7109 non-null   float64
#  32  away_sec_play_composite     7109 non-null   float64
#  33  dvoa_total_cumulative       7109 non-null   float64
#  34  dvoa_total_difference       7109 non-null   float64
#  35  dvoa_weighted_cumulative    7109 non-null   float64
#  36  dvoa_weighted_difference    7109 non-null   float64
#  37  dvoa_offense_cumulative     7109 non-null   float64
#  38  dvoa_offense_difference     7109 non-null   float64
#  39  dvoa_defense_cumulative     7109 non-null   float64
#  40  dvoa_defense_difference     7109 non-null   float64
#  41  dvoa_special_cumulative     7109 non-null   float64
#  42  dvoa_special_difference     7109 non-null   float64
#  43  dvoa_home_offense_matchup   7109 non-null   float64
#  44  dvoa_away_offense_matchup   7109 non-null   float64
#  45  composite_pace_average      7109 non-null   float64
#  46  composite_pace_difference   7109 non-null   float64
#  47  dvoa_offdefdiff_cumulative  7109 non-null   float64
#  48  dvoa_offdefdiff_difference  7109 non-null   float64
#  49  offense_matchup_cumulative  7109 non-null   float64
#  50  offense_matchup_difference  7109 non-null   float64
# dtypes: float64(40), int64(6), object(5)
# memory usage: 2.8+ MB

# %%
# Describe numeric columns
df.describe().T
# Out:
#                              count         mean          std        min  \
# index                       7109.0  3555.000000  2052.335864     1.0000
# schedule_season             7109.0  2007.230412     8.306053  1993.0000
# schedule_week               7109.0     9.170629     5.019293     1.0000
# score_home                  7109.0    22.930511    10.305748     0.0000
# score_away                  7109.0    20.541286    10.140121     0.0000
# score_total                 7109.0    43.471796    14.332492     3.0000
# over_under_line             7109.0    42.734801     4.934734    28.0000
# over_under_diff             7109.0     0.736995    13.626319   -39.5000
# over_binary                 7109.0     0.494725     0.500007     0.0000
# spread_favorite             7109.0    -5.446336     3.478727   -26.5000
# home_total_dvoa             7109.0     0.045421    18.358933   -57.7000
# home_weighted_dvoa          7109.0     0.545773    19.100311   -53.9000
# home_offense_dvoa           7109.0    -0.202687    14.205420   -43.3000
# home_defense_dvoa           7109.0    -0.199114     9.959487   -31.2000
# home_special_dvoa           7109.0     0.048896     3.915751   -15.4000
# home_off_def_difference     7109.0    -8.267717    15.639674   -59.1000
# home_sec_play_total         7109.0    27.852872     1.295978    21.9500
# home_sec_play_neutral       7109.0    30.606804     1.467490    22.2200
# home_sec_play_composite     7109.0    29.229838     1.305505    22.0850
# away_total_dvoa             7109.0    -0.143986    18.413787   -57.7000
# away_weighted_dvoa          7109.0     0.335757    19.151344   -53.9000
# away_offense_dvoa           7109.0    -0.322324    14.216992   -43.3000
# away_defense_dvoa           7109.0    -0.139654     9.946195   -31.2000
# away_special_dvoa           7109.0     0.038444     3.902091   -15.4000
# away_off_def_difference     7109.0    -8.386890    15.635721   -59.1000
# away_sec_play_total         7109.0    27.847787     1.295781    21.9500
# away_sec_play_neutral       7109.0    30.610923     1.465217    22.2200
# away_sec_play_composite     7109.0    29.229355     1.304041    22.0850
# dvoa_total_cumulative       7109.0    -0.098565    25.652155   -92.2000
# dvoa_total_difference       7109.0    21.260332    15.561924     0.0000
# dvoa_weighted_cumulative    7109.0     0.881530    26.575043   -97.0000
# dvoa_weighted_difference    7109.0    22.326684    16.076441     0.0000
# dvoa_offense_cumulative     7109.0    -0.525011    19.889268   -72.0000
# dvoa_offense_difference     7109.0    16.382318    11.993617     0.0000
# dvoa_defense_cumulative     7109.0    -0.338768    14.030297   -56.8000
# dvoa_defense_difference     7109.0    11.416500     8.308780     0.0000
# dvoa_special_cumulative     7109.0     0.087340     5.344330   -22.4000
# dvoa_special_difference     7109.0     4.530131     3.468734     0.0000
# dvoa_home_offense_matchup   7109.0    -0.342341    17.396528   -67.2000
# dvoa_away_offense_matchup   7109.0    -0.521438    17.455529   -59.6000
# composite_pace_average      7109.0    29.229597     0.935454    24.4625
# composite_pace_difference   7109.0     1.425764     1.129755     0.0000
# dvoa_offdefdiff_cumulative  7109.0   -16.654607    21.983094   -95.1000
# dvoa_offdefdiff_difference  7109.0    17.813195    13.324924     0.0000
# offense_matchup_cumulative  7109.0    -0.863778    23.847386   -84.1000
# offense_matchup_difference  7109.0    20.467576    15.067282     0.0000
#
#                                  25%       50%        75%       max
# index                       1778.000  3555.000  5332.0000  7109.000
# schedule_season             2000.000  2007.000  2014.0000  2021.000
# schedule_week                  5.000     9.000    14.0000    18.000
# score_home                    16.000    23.000    30.0000    62.000
# score_away                    13.000    20.000    27.0000    59.000
# score_total                   33.000    43.000    52.0000   106.000
# over_under_line               39.000    42.500    46.0000    63.500
# over_under_diff               -9.000    -0.500     9.5000    68.500
# over_binary                    0.000     0.000     1.0000     1.000
# spread_favorite               -7.000    -4.500    -3.0000     0.000
# home_total_dvoa              -12.600    -0.200    13.3000    53.400
# home_weighted_dvoa           -12.800     0.900    14.4000    55.900
# home_offense_dvoa            -10.100    -0.200     9.2000    44.100
# home_defense_dvoa             -7.200     0.300     6.7000    23.300
# home_special_dvoa             -2.500     0.100     2.6000    12.200
# home_off_def_difference      -18.900    -7.800     2.1000    39.600
# home_sec_play_total           27.000    27.860    28.7000    32.050
# home_sec_play_neutral         29.730    30.680    31.6100    35.020
# home_sec_play_composite       28.455    29.275    30.1250    33.005
# away_total_dvoa              -12.700    -0.400    13.2000    53.400
# away_weighted_dvoa           -13.100     0.900    14.4000    55.900
# away_offense_dvoa            -10.100    -0.300     9.1000    44.100
# away_defense_dvoa             -7.100     0.500     6.8000    23.300
# away_special_dvoa             -2.500     0.100     2.6000    12.200
# away_off_def_difference      -19.100    -8.100     1.9000    39.600
# away_sec_play_total           26.990    27.850    28.7000    32.050
# away_sec_play_neutral         29.730    30.680    31.6100    35.020
# away_sec_play_composite       28.455    29.275    30.1250    33.005
# dvoa_total_cumulative        -18.300     0.500    17.9000    83.000
# dvoa_total_difference          8.600    18.400    31.0000    91.100
# dvoa_weighted_cumulative     -17.700     0.900    19.2000    94.200
# dvoa_weighted_difference       9.500    19.300    32.3000    87.300
# dvoa_offense_cumulative      -14.000    -0.500    13.1000    67.700
# dvoa_offense_difference        6.900    14.400    23.2000    77.200
# dvoa_defense_cumulative       -9.600     0.300     9.4000    41.800
# dvoa_defense_difference        4.700    10.000    16.5000    48.600
# dvoa_special_cumulative       -3.500     0.000     3.6000    20.000
# dvoa_special_difference        1.900     3.800     6.5000    24.200
# dvoa_home_offense_matchup    -12.100    -0.100    11.5000    57.900
# dvoa_away_offense_matchup    -12.300    -0.100    11.3000    57.900
# composite_pace_average        28.665    29.280    29.8425    32.860
# composite_pace_difference      0.565     1.200     2.0250     9.390
# dvoa_offdefdiff_cumulative   -31.500   -16.800    -1.7000    52.100
# dvoa_offdefdiff_difference     7.100    15.200    25.7000    87.500
# offense_matchup_cumulative   -16.700    -1.200    15.1000    83.300
# offense_matchup_difference     8.300    17.400    30.0000    95.100

# %% [markdown]
# ## Data Pre-Processing

# %%
# define target variable and drop irrelevant columns for ML
y = df['over_binary']

X = df.drop(columns=['index', 'schedule_date', 'team_home', 'team_home_full', 'team_away', 'team_away_full', 
                     'score_home', 'score_away', 'score_total', 'over_under_diff', 'over_binary'])
X.head()
# Out:
#    schedule_season  schedule_week  over_under_line  spread_favorite  \
# 0             1993              1             38.5            -14.0
# 1             1993              1             35.0             -1.0
# 2             1993              1             35.5             -7.5
# 3             1993              1             44.0             -5.0
# 4             1993              1             38.5             -6.5
#
#    home_total_dvoa  home_weighted_dvoa  home_offense_dvoa  home_defense_dvoa  \
# 0              7.8                -2.0                2.0               -5.5
# 1             -7.2               -12.6              -14.6               -4.7
# 2              0.0                 5.6               -7.4               -2.2
# 3             -2.3                -0.4              -11.7               -4.1
# 4             10.8                 9.7               -3.4               -9.1
#
#    home_special_dvoa  home_off_def_difference  ...  dvoa_special_cumulative  \
# 0                0.4                     -3.5  ...                     -5.6
# 1                2.7                    -19.3  ...                      3.6
# 2                5.2                     -9.6  ...                      4.7
# 3                5.3                    -15.8  ...                     11.9
# 4                5.2                    -12.5  ...                     -0.7
#
#    dvoa_special_difference  dvoa_home_offense_matchup  \
# 0                      6.4                        9.6
# 1                      1.8                      -15.2
# 2                      5.7                        9.4
# 3                      1.3                       -4.3
# 4                     11.1                       16.3
#
#    dvoa_away_offense_matchup  composite_pace_average  \
# 0                      -17.7                 26.2650
# 1                        6.5                 30.6750
# 2                      -16.3                 29.9425
# 3                      -11.6                 31.4300
# 4                       -6.5                 29.4900
#
#    composite_pace_difference  dvoa_offdefdiff_cumulative  \
# 0                      3.600                       -23.3
# 1                      0.560                        -8.7
# 2                      2.565                       -40.5
# 3                      1.560                       -30.7
# 4                      0.190                       -29.6
#
#    dvoa_offdefdiff_difference  offense_matchup_cumulative  \
# 0                        16.3                        -8.1
# 1                        29.9                        -8.7
# 2                        21.3                        -6.9
# 3                         0.9                       -15.9
# 4                         4.6                         9.8
#
#    offense_matchup_difference
# 0                        27.3
# 1                        21.7
# 2                        25.7
# 3                         7.3
# 4                        22.8
#
# [5 rows x 40 columns]

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5331, 40)
# (1778, 40)

# %%
# Creating and fitting a standard scaler with the training data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

# Scaling the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Machine Learning Model

# %%
# Define classifier
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=128,
                                random_state=0)
# Fit classifier
classifier.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=128, random_state=0)

# %%
# Testing model
predictions = classifier.predict(X_test_scaled)
results = pd.DataFrame({'Prediction':predictions, 'Actual':y_test}).reset_index(drop=True)
# Create confusion matrix and accuracy score
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual Under", "Actual Over"], columns=["Predicted Under", "Predicted Over"])
logreg_acc_score = accuracy_score(y_test, predictions)
# Display results
display(cm_df)
print(f"Accuracy Score : {logreg_acc_score}")
print(classification_report(y_test, predictions))
# Out:
#               Predicted Under  Predicted Over
# Actual Under              536             362
# Actual Over               419             461
# Accuracy Score : 0.5607424071991001
#               precision    recall  f1-score   support
#
#          0.0       0.56      0.60      0.58       898
#          1.0       0.56      0.52      0.54       880
#
#     accuracy                           0.56      1778
#    macro avg       0.56      0.56      0.56      1778
# weighted avg       0.56      0.56      0.56      1778
